-- %%
%python
print("Running 01_f1_ingest_bronze...")
dbutils.notebook.run("01_f1_ingest_bronze", timeout_seconds=0)

print("Running 02_f1_transform_silver...")
dbutils.notebook.run("02_f1_transform_silver", timeout_seconds=0)

print("Running 03_f1_build_gold...")
dbutils.notebook.run("03_f1_build_gold", timeout_seconds=0)

print("Pipeline finished successfully.")
